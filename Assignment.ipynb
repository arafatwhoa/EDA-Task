# %%
import requests

# %%
r = requests.get('https://api.openaq.org/v1/cities')
r = requests.get('https://api.openaq.org/v1/countries')
r = requests.get('https://api.openaq.org/v1/locations')
r = requests.get('https://api.openaq.org/v1/measurements')
r = requests.get('https://api.openaq.org/v1/parameters')
r = requests.get('https://api.openaq.org/v1/fetches')
r = requests.get('https://api.openaq.org/beta/averages')

# %%
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '{"meta":{"name":"openaq-api","license":"CC BY 4.0","website":"https://docs.openaq.org/","page":1,"limit":100},"results":[{"country":"CN","city":"合肥市","location":"琥珀山庄","coordinates":{"longitude":117.259,"latitude":117.259},"parameter":"pm25","date":"2020-06-30","average":17.8,"measurement_count":10,"unit":"µg/m³"},{"country":"CN","city":"呼和浩特市","location":"化肥厂生活区","coordinates":{"longitude":111.717,"latitude":111.717},"parameter":"pm25","date":"2020-06-30","average":9.333333,"measurement_count":6,"unit":"µg/m³"},{"country":"CN","city":"凉山州","location":"青龙寺","coordinates":{"longitude":102.3419,"latitude":102.3419},"parameter":"pm25","date":"2020-06-30","average":4.5,"measurement_count":10,"unit":"µg/m³"},{"country":"CN","city":"合肥市","location":"庐阳区","coordinates":{"longitude":117.266,"latitude":117.266},"parameter":"pm25","date":"2020-06-30","average":20.4,"measurement_count":10,"unit":"µg/m³"},{"country":"CN","city":"合肥市","location":"董铺水库","coordinates":{"longitude":117.16,"latitude
# ...

# %%
r.json()
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': 'CC BY 4.0',
#   'website': 'https://docs.openaq.org/',
#   'page': 1,
#   'limit': 100},
#  'results': [{'country': 'CN',
#    'city': '合肥市',
#    'location': '琥珀山庄',
#    'coordinates': {'longitude': 117.259, 'latitude': 117.259},
#    'parameter': 'pm25',
#    'date': '2020-06-30',
#    'average': 17.8,
#    'measurement_count': 10,
#    'unit': 'µg/m³'},
#   {'country': 'CN',
#    'city': '呼和浩特市',
#    'location': '化肥厂生活区',
#    'coordinates': {'longitude': 111.717, 'latitude': 111.717},
#    'parameter': 'pm25',
#    'date': '2020-06-30',
#    'average': 9.333333,
#    'measurement_count': 6,
#    'unit': 'µg/m³'},
#   {'country': 'CN',
#    'city': '凉山州',
#    'location': '青龙寺',
#    'coordinates': {'longitude': 102.3419, 'latitude': 102.3419},
#    'parameter': 'pm25',
#    'date': '2020-06-30',
#    'average': 4.5,
#    'measurement_count': 10,
#    'unit': 'µg/m³'},
#   {'country': 'CN',
#    'city': '合肥市',
# ...

# %%
import pandas as pd
from pandas import DataFrame
import json

# %%
python_data = json.loads(r.text)
print (type(python_data))
python_data = python_data ['results']
print(python_data)
# Out:
# <class 'dict'>
# ...

# %%
dframe = pd.DataFrame(python_data)

# %%
dframe.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
dframe
# Out:
#       average              city  \
# 0   17.800000               合肥市
# 1    9.333333             呼和浩特市
# 2    4.500000               凉山州
# 3   20.400000               合肥市
# 4   17.888890               合肥市
# 5    7.857143             呼和浩特市
# 6    7.300000               兴安盟
# 7    6.800000               凉山州
# 8   25.400000               南充市
# 9    5.200000               厦门市
# 10  16.555555               合肥市
# 11  18.100000               合肥市
# 12  23.800000               吉安市
# 13   6.166666             呼和浩特市
# 14  13.400000               临沂市
# 15   4.100000              六盘水市
# 16  16.200000               内江市
# 17   5.555555               凉山州
# 18  25.800000               南充市
# 19  17.400000               南充市
# 20   6.250000           ONTARIO
# 21   6.900000               厦门市
# 22  14.400000               临沂市
# 23  12.000000               合肥市
# 24  20.400000               合肥市
# 25  15.400000               合肥市
# 26  25.900000               吉安市
# 27  25.100000               吉安市
# ...

# %%
dframe.columns
# Out:
# Index(['average', 'city', 'coordinates', 'country', 'date', 'location',
#        'measurement_count', 'parameter', 'unit'],
#       dtype='object')

# %%
dframe.plot.bar(x= 'city', y='average')

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] =(30,6)

# %%
import matplotlib

# %%
dframe.describe().head
# Out:
# <bound method NDFrame.head of           average  measurement_count
# count  100.000000         100.000000
# mean    10.020352           7.670000
# std      6.956819           3.068428
# min      0.719000           1.000000
# 25%      4.723571           6.000000
# 50%      7.555000           9.000000
# 75%     15.610714          10.000000
# max     26.300000          10.000000>

# %%
dframe.head()
# Out:
#      average   city                                    coordinates country  \
# 0  17.800000    合肥市    {'longitude': 117.259, 'latitude': 117.259}      CN
# 1   9.333333  呼和浩特市    {'longitude': 111.717, 'latitude': 111.717}      CN
# 2   4.500000    凉山州  {'longitude': 102.3419, 'latitude': 102.3419}      CN
# 3  20.400000    合肥市    {'longitude': 117.266, 'latitude': 117.266}      CN
# 4  17.888890    合肥市      {'longitude': 117.16, 'latitude': 117.16}      CN
#
#          date location  measurement_count parameter   unit
# 0  2020-06-30     琥珀山庄                 10      pm25  µg/m³
# 1  2020-06-30   化肥厂生活区                  6      pm25  µg/m³
# 2  2020-06-30      青龙寺                 10      pm25  µg/m³
# 3  2020-06-30      庐阳区                 10      pm25  µg/m³
# 4  2020-06-30     董铺水库                  9      pm25  µg/m³

# %%
dframe.tail()
# Out:
#       average              city  \
# 95   1.666667  Niederösterreich
# 96   7.040000         Melbourne
# 97   0.719000           Hainaut
# 98  18.100000               合肥市
# 99  10.200000             呼和浩特市
#
#                                       coordinates country        date  \
# 95  {'longitude': 15.90361, 'latitude': 15.90361}      AT  2020-06-30
# 96  {'longitude': 144.8728, 'latitude': 144.8728}      AU  2020-06-30
# 97    {'longitude': 4.52113, 'latitude': 4.52113}      BE  2020-06-30
# 98    {'longitude': 117.302, 'latitude': 117.302}      CN  2020-06-30
# 99  {'longitude': 111.5968, 'latitude': 111.5968}      CN  2020-06-30
#
#      location  measurement_count parameter   unit
# 95    AT31902                  6      pm25  µg/m³
# 96  Footscray                 10      pm25  µg/m³
# 97    BETR510                  1      pm25  µg/m³
# 98        包河区                 10      pm25  µg/m³
# 99       红旗小学                 10      pm25  µg/m³

# %%
dframe.shape
# Out:
# (100, 9)

# %%
dframe.describe()
# Out:
#           average  measurement_count
# count  100.000000         100.000000
# mean    10.020352           7.670000
# std      6.956819           3.068428
# min      0.719000           1.000000
# 25%      4.723571           6.000000
# 50%      7.555000           9.000000
# 75%     15.610714          10.000000
# max     26.300000          10.000000

# %%
dframe['measurement_count'].nunique()
# Out:
# 8

# %%
#cleaning the data

# %%
dframe.isnull().sum()
# Out:
# average              0
# city                 0
# coordinates          0
# country              0
# date                 0
# location             0
# measurement_count    0
# parameter            0
# unit                 0
# dtype: int64

# %%
dframe.head()
# Out:
#      average   city                                    coordinates country  \
# 0  17.800000    合肥市    {'longitude': 117.259, 'latitude': 117.259}      CN
# 1   9.333333  呼和浩特市    {'longitude': 111.717, 'latitude': 111.717}      CN
# 2   4.500000    凉山州  {'longitude': 102.3419, 'latitude': 102.3419}      CN
# 3  20.400000    合肥市    {'longitude': 117.266, 'latitude': 117.266}      CN
# 4  17.888890    合肥市      {'longitude': 117.16, 'latitude': 117.16}      CN
#
#          date location  measurement_count parameter   unit
# 0  2020-06-30     琥珀山庄                 10      pm25  µg/m³
# 1  2020-06-30   化肥厂生活区                  6      pm25  µg/m³
# 2  2020-06-30      青龙寺                 10      pm25  µg/m³
# 3  2020-06-30      庐阳区                 10      pm25  µg/m³
# 4  2020-06-30     董铺水库                  9      pm25  µg/m³

# %%
corelation = dframe.corr()

# %%
import seaborn as sns

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, annot = True)

# %%
dframe.parameter = ('pm25')

# %%
sns.pairplot(dframe)

# %%
sns.relplot(x= 'location', y= 'average', data = dframe)

# %%
sns.distplot(dframe['measurement_count'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.implot(x ='city', y ='measurement_count', hue = 'parameter', fit_reg=false, pallete = 'coolwarm', size = 6, aspect = 1 )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-53d8b6245352> in <module>
# ----> 1 sns.implot(x ='city', y ='measurement_count', hue = 'parameter', fit_reg=false, pallete = 'coolwarm', size = 6, aspect = 1 )
#
# AttributeError: module 'seaborn' has no attribute 'implot'

# %%
sns.regplot(x ='average', y= 'location', data=dframe, scatter = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#     821         try:
# --> 822             x = float(x)
#     823         except Exception:
#
# ...
